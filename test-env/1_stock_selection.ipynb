# %%
import pandas as pd
import numpy as np
import yfinance as yf

# %%
start_date = '2005-01-01'
end_date = '2020-12-31'

# %%
tickers = ['MMM', 'ABT', 'ABBV', 'ABMD', 'ACN', 'ATVI', 'ADBE', 'AMD', 'AAP', 'AES', 'AFL', 'A', 'APD', 'AKAM', 'ALK', 'ALB', 
           'ARE', 'ALGN', 'ALLE', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMCR', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT',
           'AWK', 'AMP', 'ABC', 'AME', 'AMGN', 'APH', 'ADI', 'ANSS', 'ANTM', 'AON', 'AOS', 'APA', 'AAPL', 'AMAT', 'APTV', 'ADM',
           'ANET', 'AJG', 'AIZ', 'T', 'ATO', 'ADSK', 'ADP', 'AZO', 'AVB', 'AVY', 'BKR', 'BLL', 'BAC', 'BBWI', 'BAX', 'BDX', 'BRK.B',
           'BBY', 'BIO', 'TECH', 'BIIB', 'BLK', 'BK', 'BA', 'BKNG', 'BWA', 'BXP', 'BSX', 'BMY', 'AVGO', 'BR', 'BRO', 'BF.B', 'CHRW',
           'CDNS', 'CZR', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'CARR', 'CTLT', 'CAT', 'CBOE', 'CBRE', 'CDW', 'CE', 'CNC', 'CNP', 'CDAY',
           'CERN', 'CF', 'CRL', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CTXS', 'CLX',
           'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'COP', 'ED', 'STZ', 'COO', 'CPRT', 'GLW', 'CTVA', 'COST', 'CTRA',
           'CCI', 'CSX', 'CMI', 'CVS', 'DHI', 'DHR', 'DRI', 'DVA', 'DE', 'DAL', 'XRAY', 'DVN', 'DXCM', 'FANG', 'DLR', 'DFS', 'DISCA',
           'DISCK', 'DISH', 'DG', 'DLTR', 'D', 'DPZ', 'DOV', 'DOW', 'DTE', 'DUK', 'DRE', 'DD', 'DXC', 'EMN', 'ETN', 'EBAY', 'ECL',
           'EIX', 'EW', 'EA', 'EMR', 'ENPH', 'ETR', 'EOG', 'EFX', 'EQIX', 'EQR', 'ESS', 'EL', 'ETSY', 'EVRG', 'ES', 'RE', 'EXC', 'EXPE',
           'EXPD', 'EXR', 'XOM', 'FFIV', 'FB', 'FAST', 'FRT', 'FDX', 'FIS', 'FITB', 'FE', 'FRC', 'FISV', 'FLT', 'FMC', 'F', 'FTNT', 'FTV',
           'FBHS', 'FOXA', 'FOX', 'BEN', 'FCX', 'GPS', 'GRMN', 'IT', 'GNRC', 'GD', 'GE', 'GIS', 'GM', 'GPC', 'GILD', 'GL', 'GPN', 'GS',
           'GWW', 'HAL', 'HBI', 'HIG', 'HAS', 'HCA', 'PEAK', 'HSIC', 'HSY', 'HES', 'HPE', 'HLT', 'HOLX', 'HD', 'HON', 'HRL', 'HST', 'HWM',
           'HPQ', 'HUM', 'HBAN', 'HII', 'IEX', 'IDXX', 'INFO', 'ITW', 'ILMN', 'INCY', 'IR', 'INTC', 'ICE', 'IBM', 'IP', 'IPG', 'IFF', 'INTU',
           'ISRG', 'IVZ', 'IPGP', 'IQV', 'IRM', 'JKHY', 'J', 'JBHT', 'SJM', 'JNJ', 'JCI', 'JPM', 'JNPR', 'KSU', 'K', 'KEY', 'KEYS', 'KMB',
           'KIM', 'KMI', 'KLAC', 'KHC', 'KR', 'LHX', 'LH', 'LRCX', 'LW', 'LVS', 'LEG', 'LDOS', 'LEN', 'LLY', 'LNC', 'LIN', 'LYV', 'LKQ', 
           'LMT', 'L', 'LOW', 'LUMN', 'LYB', 'MTB', 'MRO', 'MPC', 'MKTX', 'MAR', 'MMC', 'MLM', 'MAS', 'MA', 'MTCH', 'MKC', 'MCD', 'MCK', 'MDT',
           'MRK', 'MET', 'MTD', 'MGM', 'MCHP', 'MU', 'MSFT', 'MAA', 'MHK', 'TAP', 'MDLZ', 'MPWR', 'MNST', 'MCO', 'MS', 'MOS', 'MSI', 'MSCI',
           'NDAQ', 'NTAP', 'NFLX', 'NWL', 'NEM', 'NWSA', 'NWS', 'NEE', 'NLSN', 'NKE', 'NI', 'NSC', 'NTRS', 'NOC', 'NLOK', 'NCLH', 'NRG', 'NUE',
           'NVDA', 'NVR', 'NXPI', 'ORLY', 'OXY', 'ODFL', 'OMC', 'OKE', 'ORCL', 'OGN', 'OTIS', 'PCAR', 'PKG', 'PH', 'PAYX', 'PAYC', 'PYPL', 
           'PENN', 'PNR', 'PBCT', 'PEP', 'PKI', 'PFE', 'PM', 'PSX', 'PNW', 'PXD', 'PNC', 'POOL', 'PPG', 'PPL', 'PFG', 'PG', 'PGR', 'PLD', 
           'PRU', 'PTC', 'PEG', 'PSA', 'PHM', 'PVH', 'QRVO', 'PWR', 'QCOM', 'DGX', 'RL', 'RJF', 'RTX', 'O', 'REG', 'REGN', 'RF', 'RSG', 
           'RMD', 'RHI', 'ROK', 'ROL', 'ROP', 'ROST', 'RCL', 'SPGI', 'CRM', 'SBAC', 'SLB', 'STX', 'SEE', 'SRE', 'NOW', 'SHW', 'SPG', 'SWKS',
           'SNA', 'SO', 'LUV', 'SWK', 'SBUX', 'STT', 'STE', 'SYK', 'SIVB', 'SYF', 'SNPS', 'SYY', 'TMUS', 'TROW', 'TTWO', 'TPR', 'TGT', 'TEL',
           'TDY', 'TFX', 'TER', 'TSLA', 'TXN', 'TXT', 'TMO', 'TJX', 'TSCO', 'TT', 'TDG', 'TRV', 'TRMB', 'TFC', 'TWTR', 'TYL', 'TSN', 'UDR',
           'ULTA', 'USB', 'UAA', 'UA', 'UNP', 'UAL', 'UNH', 'UPS', 'URI', 'UHS', 'VLO', 'VTR', 'VRSN', 'VRSK', 'VZ', 'VRTX', 'VFC', 'VIAC', 
           'VTRS', 'V', 'VNO', 'VMC', 'WRB', 'WAB', 'WMT', 'WBA', 'DIS', 'WM', 'WAT', 'WEC', 'WFC', 'WELL', 'WST', 'WDC', 'WU', 'WRK', 'WY', 
           'WHR', 'WMB', 'WLTW', 'WYNN', 'XEL', 'XLNX', 'XYL', 'YUM', 'ZBRA', 'ZBH', 'ZION', 'ZTS']

# %%
sp500 = yf.download(tickers, start=start_date, end=end_date)
# Out:
# C:\Users\drebi\AppData\Local\Temp\ipykernel_44504\3868537152.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   sp500 = yf.download(tickers, start=start_date, end=end_date)
# [*********************100%***********************]  504 of 504 completed
#
# 43 Failed downloads:
# ['DFS', 'KSU', 'PEAK', 'CERN', 'JNPR', 'ANSS', 'FRC', 'TWTR', 'ABMD', 'CTXS', 'BRK.B', 'NLOK', 'GPS', 'VIAC', 'FLT', 'CTLT', 'FBHS', 'RE', 'WRK', 'HES', 'DISH', 'ABC', 'ANTM', 'PXD', 'DISCK', 'FISV', 'ATVI', 'CDAY', 'NLSN', 'DRE', 'DISCA', 'SIVB', 'BLL', 'XLNX', 'PKI', 'WLTW', 'MRO', 'PBCT']: YFTzMissingError('possibly delisted; no timezone found')
# ['BF.B']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-01-01 -> 2020-12-31)')
# ['FB', 'INFO', 'OGN']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-01-01 -> 2020-12-31) (Yahoo error = "Data doesn\'t exist for startDate = 1104555600, endDate = 1609390800")')
# ['WBA']: YFPricesMissingError('possibly delisted; no price data found  (1d 2005-01-01 -> 2020-12-31) (Yahoo error = "No data found, symbol may be delisted")')

# %%
sp500.head()
# Out:
# Price      Adj Close                                               ...  \
# Ticker           ABC ABMD ANSS ANTM ATVI BF.B BLL BRK.B CDAY CERN  ...
# Date                                                               ...
# 2005-01-03       NaN  NaN  NaN  NaN  NaN  NaN NaN   NaN  NaN  NaN  ...
# 2005-01-04       NaN  NaN  NaN  NaN  NaN  NaN NaN   NaN  NaN  NaN  ...
# 2005-01-05       NaN  NaN  NaN  NaN  NaN  NaN NaN   NaN  NaN  NaN  ...
# 2005-01-06       NaN  NaN  NaN  NaN  NaN  NaN NaN   NaN  NaN  NaN  ...
# 2005-01-07       NaN  NaN  NaN  NaN  NaN  NaN NaN   NaN  NaN  NaN  ...
#
# Price        Volume                                                         \
# Ticker          XEL XLNX       XOM     XRAY XYL      YUM      ZBH     ZBRA
# Date
# 2005-01-03   879200  NaN  16009200  1022000 NaN  3257166  1478256   443500
# 2005-01-04  1220300  NaN  16718000   616000 NaN  3228789  1271638   696500
# 2005-01-05  1430000  NaN  12189100   675600 NaN  2126839  1218799  1054400
# 2005-01-06  1019200  NaN  13098700   475600 NaN  1802458  1193667   280000
# 2005-01-07  1267600  NaN  11315300   487800 NaN  2023349  1176466   351600
#
# Price
# Ticker        ZION ZTS
# Date
# 2005-01-03  347900 NaN
# 2005-01-04  388200 NaN
# 2005-01-05  602100 NaN
# 2005-01-06  321100 NaN
# 2005-01-07  806100 NaN
#
# [5 rows x 2563 columns]

# %%
df_close = sp500['Close']
df_close.shape
# Out:
# (4027, 504)

# %%
df_close.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4027 entries, 2005-01-03 to 2020-12-30
# Data columns (total 504 columns):
#  #    Column  Dtype
# ---   ------  -----
#  0    A       float64
#  1    AAL     float64
#  2    AAP     float64
#  3    AAPL    float64
#  4    ABBV    float64
#  5    ABC     float64
#  6    ABMD    float64
#  7    ABT     float64
#  8    ACN     float64
#  9    ADBE    float64
#  10   ADI     float64
#  11   ADM     float64
#  12   ADP     float64
#  13   ADSK    float64
#  14   AEE     float64
#  15   AEP     float64
#  16   AES     float64
#  17   AFL     float64
#  18   AIG     float64
#  19   AIZ     float64
#  20   AJG     float64
#  21   AKAM    float64
#  22   ALB     float64
#  23   ALGN    float64
#  24   ALK     float64
#  25   ALL     float64
#  26   ALLE    float64
#  27   AMAT    float64
#  28   AMCR    float64
#  29   AMD     float64
#  30   AME     float64
#  31   AMGN    float64
#  32   AMP     float64
#  33   AMT     float64
#  34   AMZN    float64
#  35   ANET    float64
#  36   ANSS    float64
#  37   ANTM    float64
#  38   AON     float64
#  39   AOS     float64
#  40   APA     float64
#  41   APD     float64
#  42   APH     float64
#  43   APTV    float64
#  44   ARE     float64
#  45   ATO     float64
#  46   ATVI    float64
#  47   AVB     float64
#  48   AVGO    float64
#  49   AVY     float64
#  50   AWK     float64
#  51   AXP     float64
#  52   AZO     float64
#  53   BA      float64
#  54   BAC     float64
#  55   BAX     float64
#  56   BBWI    float64
#  57   BBY     float64
#  58   BDX     float64
#  59   BEN     float64
#  60   BF.B    float64
#  61   BIIB    float64
#  62   BIO     float64
#  63   BK      float64
#  64   BKNG    float64
#  65   BKR     float64
#  66   BLK     float64
#  67   BLL     float64
#  68   BMY     float64
#  69   BR      float64
#  70   BRK.B   float64
#  71   BRO     float64
#  72   BSX     float64
#  73   BWA     float64
#  74   BXP     float64
#  75   C       float64
#  76   CAG     float64
#  77   CAH     float64
#  78   CARR    float64
#  79   CAT     float64
#  80   CB      float64
#  81   CBOE    float64
#  82   CBRE    float64
#  83   CCI     float64
#  84   CCL     float64
#  85   CDAY    float64
#  86   CDNS    float64
#  87   CDW     float64
#  88   CE      float64
#  89   CERN    float64
#  90   CF      float64
#  91   CFG     float64
#  92   CHD     float64
#  93   CHRW    float64
#  94   CHTR    float64
#  95   CI      float64
#  96   CINF    float64
#  97   CL      float64
#  98   CLX     float64
#  99   CMA     float64
#  100  CMCSA   float64
#  101  CME     float64
#  102  CMG     float64
#  103  CMI     float64
#  104  CMS     float64
#  105  CNC     float64
#  106  CNP     float64
#  107  COF     float64
#  108  COO     float64
#  109  COP     float64
#  110  COST    float64
#  111  CPB     float64
#  112  CPRT    float64
#  113  CRL     float64
#  114  CRM     float64
#  115  CSCO    float64
#  116  CSX     float64
#  117  CTAS    float64
#  118  CTLT    float64
#  119  CTRA    float64
#  120  CTSH    float64
#  121  CTVA    float64
#  122  CTXS    float64
#  123  CVS     float64
#  124  CVX     float64
#  125  CZR     float64
#  126  D       float64
#  127  DAL     float64
#  128  DD      float64
#  129  DE      float64
#  130  DFS     float64
#  131  DG      float64
#  132  DGX     float64
#  133  DHI     float64
#  134  DHR     float64
#  135  DIS     float64
#  136  DISCA   float64
#  137  DISCK   float64
#  138  DISH    float64
#  139  DLR     float64
#  140  DLTR    float64
#  141  DOV     float64
#  142  DOW     float64
#  143  DPZ     float64
#  144  DRE     float64
#  145  DRI     float64
#  146  DTE     float64
#  147  DUK     float64
#  148  DVA     float64
#  149  DVN     float64
#  150  DXC     float64
#  151  DXCM    float64
#  152  EA      float64
#  153  EBAY    float64
#  154  ECL     float64
#  155  ED      float64
#  156  EFX     float64
#  157  EIX     float64
#  158  EL      float64
#  159  EMN     float64
#  160  EMR     float64
#  161  ENPH    float64
#  162  EOG     float64
#  163  EQIX    float64
#  164  EQR     float64
#  165  ES      float64
#  166  ESS     float64
#  167  ETN     float64
#  168  ETR     float64
#  169  ETSY    float64
#  170  EVRG    float64
#  171  EW      float64
#  172  EXC     float64
#  173  EXPD    float64
#  174  EXPE    float64
#  175  EXR     float64
#  176  F       float64
#  177  FANG    float64
#  178  FAST    float64
#  179  FB      float64
#  180  FBHS    float64
#  181  FCX     float64
#  182  FDX     float64
#  183  FE      float64
#  184  FFIV    float64
#  185  FIS     float64
#  186  FISV    float64
#  187  FITB    float64
#  188  FLT     float64
#  189  FMC     float64
#  190  FOX     float64
#  191  FOXA    float64
#  192  FRC     float64
#  193  FRT     float64
#  194  FTNT    float64
#  195  FTV     float64
#  196  GD      float64
#  197  GE      float64
#  198  GILD    float64
#  199  GIS     float64
#  200  GL      float64
#  201  GLW     float64
#  202  GM      float64
#  203  GNRC    float64
#  204  GOOG    float64
#  205  GOOGL   float64
#  206  GPC     float64
#  207  GPN     float64
#  208  GPS     float64
#  209  GRMN    float64
#  210  GS      float64
#  211  GWW     float64
#  212  HAL     float64
#  213  HAS     float64
#  214  HBAN    float64
#  215  HBI     float64
#  216  HCA     float64
#  217  HD      float64
#  218  HES     float64
#  219  HIG     float64
#  220  HII     float64
#  221  HLT     float64
#  222  HOLX    float64
#  223  HON     float64
#  224  HPE     float64
#  225  HPQ     float64
#  226  HRL     float64
#  227  HSIC    float64
#  228  HST     float64
#  229  HSY     float64
#  230  HUM     float64
#  231  HWM     float64
#  232  IBM     float64
#  233  ICE     float64
#  234  IDXX    float64
#  235  IEX     float64
#  236  IFF     float64
#  237  ILMN    float64
#  238  INCY    float64
#  239  INFO    float64
#  240  INTC    float64
#  241  INTU    float64
#  242  IP      float64
#  243  IPG     float64
#  244  IPGP    float64
#  245  IQV     float64
#  246  IR      float64
#  247  IRM     float64
#  248  ISRG    float64
#  249  IT      float64
#  250  ITW     float64
#  251  IVZ     float64
#  252  J       float64
#  253  JBHT    float64
#  254  JCI     float64
#  255  JKHY    float64
#  256  JNJ     float64
#  257  JNPR    float64
#  258  JPM     float64
#  259  K       float64
#  260  KEY     float64
#  261  KEYS    float64
#  262  KHC     float64
#  263  KIM     float64
#  264  KLAC    float64
#  265  KMB     float64
#  266  KMI     float64
#  267  KMX     float64
#  268  KO      float64
#  269  KR      float64
#  270  KSU     float64
#  271  L       float64
#  272  LDOS    float64
#  273  LEG     float64
#  274  LEN     float64
#  275  LH      float64
#  276  LHX     float64
#  277  LIN     float64
#  278  LKQ     float64
#  279  LLY     float64
#  280  LMT     float64
#  281  LNC     float64
#  282  LNT     float64
#  283  LOW     float64
#  284  LRCX    float64
#  285  LUMN    float64
#  286  LUV     float64
#  287  LVS     float64
#  288  LW      float64
#  289  LYB     float64
#  290  LYV     float64
#  291  MA      float64
#  292  MAA     float64
#  293  MAR     float64
#  294  MAS     float64
#  295  MCD     float64
#  296  MCHP    float64
#  297  MCK     float64
#  298  MCO     float64
#  299  MDLZ    float64
#  300  MDT     float64
#  301  MET     float64
#  302  MGM     float64
#  303  MHK     float64
#  304  MKC     float64
#  305  MKTX    float64
#  306  MLM     float64
#  307  MMC     float64
#  308  MMM     float64
#  309  MNST    float64
#  310  MO      float64
#  311  MOS     float64
#  312  MPC     float64
#  313  MPWR    float64
#  314  MRK     float64
#  315  MRO     float64
#  316  MS      float64
#  317  MSCI    float64
#  318  MSFT    float64
#  319  MSI     float64
#  320  MTB     float64
#  321  MTCH    float64
#  322  MTD     float64
#  323  MU      float64
#  324  NCLH    float64
#  325  NDAQ    float64
#  326  NEE     float64
#  327  NEM     float64
#  328  NFLX    float64
#  329  NI      float64
#  330  NKE     float64
#  331  NLOK    float64
#  332  NLSN    float64
#  333  NOC     float64
#  334  NOW     float64
#  335  NRG     float64
#  336  NSC     float64
#  337  NTAP    float64
#  338  NTRS    float64
#  339  NUE     float64
#  340  NVDA    float64
#  341  NVR     float64
#  342  NWL     float64
#  343  NWS     float64
#  344  NWSA    float64
#  345  NXPI    float64
#  346  O       float64
#  347  ODFL    float64
#  348  OGN     float64
#  349  OKE     float64
#  350  OMC     float64
#  351  ORCL    float64
#  352  ORLY    float64
#  353  OTIS    float64
#  354  OXY     float64
#  355  PAYC    float64
#  356  PAYX    float64
#  357  PBCT    float64
#  358  PCAR    float64
#  359  PEAK    float64
#  360  PEG     float64
#  361  PENN    float64
#  362  PEP     float64
#  363  PFE     float64
#  364  PFG     float64
#  365  PG      float64
#  366  PGR     float64
#  367  PH      float64
#  368  PHM     float64
#  369  PKG     float64
#  370  PKI     float64
#  371  PLD     float64
#  372  PM      float64
#  373  PNC     float64
#  374  PNR     float64
#  375  PNW     float64
#  376  POOL    float64
#  377  PPG     float64
#  378  PPL     float64
#  379  PRU     float64
#  380  PSA     float64
#  381  PSX     float64
#  382  PTC     float64
#  383  PVH     float64
#  384  PWR     float64
#  385  PXD     float64
#  386  PYPL    float64
#  387  QCOM    float64
#  388  QRVO    float64
#  389  RCL     float64
#  390  RE      float64
#  391  REG     float64
#  392  REGN    float64
#  393  RF      float64
#  394  RHI     float64
#  395  RJF     float64
#  396  RL      float64
#  397  RMD     float64
#  398  ROK     float64
#  399  ROL     float64
#  400  ROP     float64
#  401  ROST    float64
#  402  RSG     float64
#  403  RTX     float64
#  404  SBAC    float64
#  405  SBUX    float64
#  406  SCHW    float64
#  407  SEE     float64
#  408  SHW     float64
#  409  SIVB    float64
#  410  SJM     float64
#  411  SLB     float64
#  412  SNA     float64
#  413  SNPS    float64
#  414  SO      float64
#  415  SPG     float64
#  416  SPGI    float64
#  417  SRE     float64
#  418  STE     float64
#  419  STT     float64
#  420  STX     float64
#  421  STZ     float64
#  422  SWK     float64
#  423  SWKS    float64
#  424  SYF     float64
#  425  SYK     float64
#  426  SYY     float64
#  427  T       float64
#  428  TAP     float64
#  429  TDG     float64
#  430  TDY     float64
#  431  TECH    float64
#  432  TEL     float64
#  433  TER     float64
#  434  TFC     float64
#  435  TFX     float64
#  436  TGT     float64
#  437  TJX     float64
#  438  TMO     float64
#  439  TMUS    float64
#  440  TPR     float64
#  441  TRMB    float64
#  442  TROW    float64
#  443  TRV     float64
#  444  TSCO    float64
#  445  TSLA    float64
#  446  TSN     float64
#  447  TT      float64
#  448  TTWO    float64
#  449  TWTR    float64
#  450  TXN     float64
#  451  TXT     float64
#  452  TYL     float64
#  453  UA      float64
#  454  UAA     float64
#  455  UAL     float64
#  456  UDR     float64
#  457  UHS     float64
#  458  ULTA    float64
#  459  UNH     float64
#  460  UNP     float64
#  461  UPS     float64
#  462  URI     float64
#  463  USB     float64
#  464  V       float64
#  465  VFC     float64
#  466  VIAC    float64
#  467  VLO     float64
#  468  VMC     float64
#  469  VNO     float64
#  470  VRSK    float64
#  471  VRSN    float64
#  472  VRTX    float64
#  473  VTR     float64
#  474  VTRS    float64
#  475  VZ      float64
#  476  WAB     float64
#  477  WAT     float64
#  478  WBA     float64
#  479  WDC     float64
#  480  WEC     float64
#  481  WELL    float64
#  482  WFC     float64
#  483  WHR     float64
#  484  WLTW    float64
#  485  WM      float64
#  486  WMB     float64
#  487  WMT     float64
#  488  WRB     float64
#  489  WRK     float64
#  490  WST     float64
#  491  WU      float64
#  492  WY      float64
#  493  WYNN    float64
#  494  XEL     float64
#  495  XLNX    float64
#  496  XOM     float64
#  497  XRAY    float64
#  498  XYL     float64
#  499  YUM     float64
#  500  ZBH     float64
#  501  ZBRA    float64
#  502  ZION    float64
#  503  ZTS     float64
# dtypes: float64(504)
# memory usage: 15.5 MB

# %%
df_close.isnull().sum()
# Out:
# Ticker
# A          0
# AAL      185
# AAP        0
# AAPL       0
# ABBV    2013
#         ...
# YUM        0
# ZBH        0
# ZBRA       0
# ZION       0
# ZTS     2034
# Length: 504, dtype: int64

# %%
daily_volatility    = df_close.pct_change().apply(lambda x: np.log(1+x)).std()     
weekly_volatility   = daily_volatility.pct_change().apply(lambda x: x*np.sqrt(5))
# Out:
# C:\Users\drebi\AppData\Local\Temp\ipykernel_44504\3794868601.py:1: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   daily_volatility    = df_close.pct_change().apply(lambda x: np.log(1+x)).std()
# C:\Users\drebi\AppData\Local\Temp\ipykernel_44504\3794868601.py:2: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   weekly_volatility   = daily_volatility.pct_change().apply(lambda x: x*np.sqrt(5))

# %%
WV = pd.DataFrame(
    weekly_volatility
).reset_index()
WV.columns = ["Tick", "Volatility"]

# %%
sorted_weekly_volatility = WV.sort_values(by='Volatility', ascending=False)

# %%
sorted_weekly_volatility.head()
# Out:
#      Tick  Volatility
# 161  ENPH    4.291320
# 260   KEY    3.626317
# 127   DAL    3.534441
# 281   LNC    3.493466
# 169  ETSY    3.471656

# %%
sorted_weekly_volatility.tail(6)
# Out:
#     Tick  Volatility
# 494  XEL   -1.397401
# 365   PG   -1.399373
# 282  LNT   -1.407333
# 362  PEP   -1.421716
# 126    D   -1.488911
# 0      A         NaN
